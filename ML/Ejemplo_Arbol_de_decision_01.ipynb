# %%
# Importar la biblioteca pandas para la manipulacion de datos
import pandas as pd
# Importar la clase DecisionTreeClassifier de scikit-learn para crear un modelo de Arbol de Decision
from sklearn.tree import DecisionTreeClassifier
# Importar la funcion train_test_split de scikit-learn para dividir los datos en
# conjuntos de entrenamiento y prueba
from sklearn.model_selection import train_test_split
# Importar la funcion accuracy_score de scikit-learn para calcular la precision del modelo
from sklearn.metrics import accuracy_score
# Importar la biblioteca matplolib para la visualizacion de graficos
import matplotlib.pyplot as plt
# Importar la biblioteca numpy para operaciones numericas
import numpy as np

# %%
# Cargar los datos desde un archivo excel
peliculas = pd.read_excel("/content/drive/MyDrive/Avance 03/Pelicula.xlsx", index_col=0)
peliculas.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b8b83423b71> in <cell line: 2>()
#       1 # Cargar los datos desde un archivo excel
# ----> 2 peliculas = pd.read_excel("/content/drive/MyDrive/Avance 03/Pelicula.xlsx", index_col=0)
#       3 peliculas.head(10)
#
# NameError: name 'pd' is not defined

# %%
peliculas.info()

# %%
#Variables Predictoras
X = peliculas.iloc[:,1:4]
#Variables a Predecir
Y = peliculas.iloc[:,0]
# Mostramos las 5 primeras filas
X.head()
# Out:
#     Sala  Remuneracion   Año
# ID
# 1   1.00           250  1987
# 2   0.25           275  1970
# 3   1.00           325  1951
# 4   0.75           250  1986
# 5   0.00           275  1997

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.55)
# Crear y entrenar el modelo de Arbol de decision
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(x_test)

# %%
# Calcular la precision del modelo
precision = accuracy_score(y_test, y_pred)
print("Precision del modelo:", precision*100,"%")
# Out:
# Precision del modelo: 97.77777777777777 %

# %%
from sklearn import tree
f = plt.figure(figsize=(25,20))
tree.plot_tree(model, feature_names=list(X.columns.values),class_names=list(Y.values), filled=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
f.savefig("Arbol de decision Final.png")

# %%
A = peliculas['Genero']
B = peliculas['Remuneracion']

# %%
po =plt.figure(figsize=(11,6))
plt.bar(A,B, color='blue')
plt.xticks(rotation=45)
# Establecer etiquetas y titulos del Grafico
plt.xlabel('Genero de Peliculas')
plt.ylabel('Impacto de Remuneracion al Negocio)')
plt.title('Prediccion de los generos al Impacto de Remuneracion')
# Ajustar los limites del eje Y
plt.ylim([-0, 500.1])
# Mostrar una cuadricula en el grafico
plt.grid(True, linestyle='--')
# Mostrar el grafico
plt.tight_layout()
plt.show()

# %%
po.savefig("Prediccion 01.png")
